# %% [markdown]
# # Undertake sensitivity analysis and optimisation
#
# model_optimisation_env

# %% [markdown]
# ### import packages

# %%
# %%time

import sys
import os
import numpy as np
import pandas as pd
import scipy as sci
from scipy.stats import gaussian_kde, skew, pearsonr
from scipy.special import expit, logit
from scipy.optimize import differential_evolution
import random

import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.gridspec import GridSpec
import matplotlib.colors as mcolors
import cmocean.cm as cmo
from cmocean.tools import lighten
import seaborn as sns

import SALib as SAL
from SALib.sample import saltelli
from SALib.analyze import sobol

import sklearn as skl
from sklearn import gaussian_process
from sklearn.gaussian_process.kernels import Matern,WhiteKernel,ConstantKernel,RBF
from sklearn.gaussian_process.kernels import DotProduct,ExpSineSquared,RationalQuadratic
from sklearn.utils import resample
from sklearn.metrics import r2_score

import joblib
from joblib import Parallel, delayed
from multiprocessing import Pool

import emcee

import warnings
warnings.filterwarnings('ignore')

# print versions of packages
print("python version =",sys.version[:5])
print("numpy version =", np.__version__)
print("pandas version =", pd.__version__)
print("scipy version =", sci.__version__)
print("matplotlib version =", sys.modules[plt.__package__].__version__)
print("cmocean version =", sys.modules[cmo.__package__].__version__)
print("sklearn version =", skl.__version__)
print("SALib version =", SAL.__version__)
print("seaborn version =", sns.__version__)
print("emcee version =", emcee.__version__)


wrkdir="/g/data/vn19/pjb581/WOMBATmid-Optimization/SOTSexps/data/"
os.chdir(wrkdir)
os.getcwd()
os.listdir()
# Out:
# python version = 3.10.
# numpy version = 1.26.4
# pandas version = 2.3.3
# scipy version = 1.15.3
# matplotlib version = 3.10.6
# cmocean version = v3.0.3
# sklearn version = 1.7.2
# SALib version = 1.4.7
# seaborn version = 0.13.2
# emcee version = 3.1.6
# CPU times: user 2.55 s, sys: 1.74 s, total: 4.29 s
# Wall time: 1min 2s
# ['BIAS_optimal.xlsx',
#  'BIAS.xlsx',
#  'GPR_pco2_cost.joblib',
#  'GPR_pco2_rmse.joblib',
#  'NSDEV.xlsx',
#  'NRMSE_optimal.xlsx',
#  'parameter_ranges.xlsx',
#  'SDEV_opt.xlsx',
#  'optimisation_norm_2048.txt',
#  'GPR_chl_bottle_cost.joblib',
#  'apriori_parameter_ranges.xlsx',
#  'GPR_fgco2_rmse.joblib',
#  'CCOEF_opt.xlsx',
#  'GPR_no3.joblib',
#  'GPR_poc_cost.joblib',
#  'GPR_sil.joblib',
#  'GPR_sil_cost.joblib',
#  'GPR_fgco2.joblib',
#  'SDEV.xlsx',
#  'GPR_pco2.joblib',
#  'mcmc_wombat_mid_26params_1M_rmse_withSIL.h5',
#  'CCOEF_optimal.xlsx',
#  'mcmc_wombat_mid_26params_1M_rmse.h5',
#  'GPR_sil_rmse.joblib',
#  'GPR_fgco2_cost.joblib',
#  'NSDEV_optimal.xlsx',
#  'GPR_chl_bottle_rmse.joblib',
#  'GPR_b1mb2.joblib',
#  'NRMSE.xlsx',
#  'CCOEF.xlsx',
#  'parameter_sets_1024.xlsx',
#  'GPR_b1mb2_rmse.joblib',
#  'poc_attenuation_fits_100exp_optimal.nc',
#  'GPR_nh4_rmse.joblib',
#  'GPR_no3_rmse.joblib',
#  'parameter_NRMSEpredicted_optimal100.txt',
#  'GPR_micro_rmse.joblib',
#  'GPR_poc_rmse.joblib',
#  'optimisation_sets_2048.txt',
#  'GPR_D2L300mD2L50.joblib',
#  'parameter_sets_2048.txt',
#  'poc_attenuation_fits_200exp_optimal.nc',
#  'SDEV_optimal.xlsx',
#  'mcmc_wombat_mid_26params_1M_rmse_all_P33safe.h5',
#  'GPR_dfe_rmse.joblib',
#  'optimisation_norm_2048.xlsx',
#  'GPR_D2L300mD2L50_cost.joblib',
#  'GPR_b1mb2_cost.joblib',
#  'GPR_chl_mooring_rmse.joblib',
#  'GPR_meso_rmse.joblib',
#  'parameter_sets_1024.txt',
#  'RMSE_optimal.xlsx',
#  'parameter_norm_2048.xlsx',
#  'RMSE_opt.xlsx',
#  'NRMSE_opt.xlsx',
#  'GPR_chl_mooring_cost.joblib',
#  'GPR_D2L300mD2L50_rmse.joblib',
#  'RMSE.xlsx',
#  'mcmc_wombat_mid_26params_1M_rmse_all.h5',
#  'mcmc_wombat_mid_26params_1M.h5',
#  'GPR_nh4.joblib',
#  'parameter_sets_optimal100.txt',
#  'GPR_dfe_cost.joblib',
#  'GPR_bac_rmse.joblib',
#  'parameter_sets_2048.xlsx',
#  'parameter_sets.xlsx',
#  'parameter_norm_1024.txt',
#  'parameter_sets.txt',
#  'parameter_norm_optimal100.txt',
#  'GPR_nh4_cost.joblib',
#  'GPR_chl_bottle.joblib',
#  'parameter_norm_1024.xlsx',
#  'parameter_norm_2048.txt',
#  'NSDEV_opt.xlsx',
#  'BIAS_opt.xlsx',
#  'GPR_poc.joblib',
#  'optimisation_sets_2048.xlsx',
#  'GPR_no3_cost.joblib',
#  'poc_attenuation_fits_2048exp_optimisation.nc',
#  'poc_attenuation_fits_2048exp.nc',
#  'GPR_chl_mooring.joblib',
#  'GPR_dfe.joblib']

# %% [markdown]
# ### read in the normalised parameter sets that were used as input for the forward model runs

# %%
# %%time
X = pd.read_excel('optimisation_norm_2048.xlsx', header=0, usecols=lambda column: column != 'Unnamed: 0')
param_names = X.columns
X
# Out:
# CPU times: user 1.07 s, sys: 168 ms, total: 1.24 s
# Wall time: 7.45 s
#       alphabio_phy  abioa_phy  bbioa_phy  alphabio_dia  abioa_dia     phykf  \
# 0         0.987100   0.802393   0.011476      0.175775   0.829965  0.020376
# 1         0.241883   0.158797   0.572349      0.767199   0.263895  0.762453
# 2         0.490577   0.660578   0.434263      0.441765   0.157675  0.561715
# 3         0.737440   0.300123   0.997536      0.599842   0.748708  0.288267
# 4         0.571649   0.597560   0.646422      0.743365   0.584996  0.149076
# ...            ...        ...        ...           ...        ...       ...
# 2043      0.571823   0.297585   0.388330      0.997507   0.160803  0.799672
# 2044      0.738244   0.593808   0.223831      0.846169   0.012746  0.638023
# 2045      0.490769   0.491405   0.661036      0.187594   0.580894  0.395783
# 2046      0.241599   0.986112   0.330430      0.521341   0.997661  0.162822
# 2047      0.986449   0.100566   0.769080      0.429415   0.408456  0.936184
#
#       phymaxqc   phylmor     diakf  diaVmaxs  ...  kcoag_dfe  bsi_kbac  \
# 0     0.028623  0.305757  0.718250  0.069816  ...   0.555513  0.143579
# 1     0.967374  0.727332  0.219914  0.827004  ...   0.329462  0.806904
# 2     0.260570  0.772870  0.491398  0.528637  ...   0.242787  0.457236
# 3     0.696329  0.194072  0.946767  0.270466  ...   0.891708  0.622524
# 4     0.468335  0.880377  0.290677  0.973678  ...   0.090301  0.342865
# ...        ...       ...       ...       ...  ...        ...       ...
# 2043  0.386711  0.926273  0.747519  0.621574  ...   0.416170  0.026553
# 2044  0.653716  0.241927  0.028991  0.138188  ...   0.600846  0.805976
# 2045  0.342529  0.787515  0.535048  0.879054  ...   0.264415  0.140696
# 2046  0.885720  0.712680  0.802626  0.710632  ...   0.163090  0.623421
# 2047  0.071421  0.257908  0.261412  0.466828  ...   0.951690  0.460088
#
#        aoalmor   Hox_fac   Oox_fac   Nox_fac  bac1_kpoc  bac1lmor  bac1_alpha  \
# 0     0.412091  0.954306  0.844823  0.527124   0.495471  0.720470    0.593533
# 1     0.500550  0.264641  0.163461  0.014406   0.768956  0.449117    0.307260
# 2     0.964330  0.686768  0.380826  0.865541   0.194107  0.954590    0.141290
# 3     0.123117  0.094283  0.565966  0.347010   0.545844  0.245757    0.990033
# 4     0.685219  0.854911  0.937347  0.884779   0.360377  0.055201    0.083517
# ...        ...       ...       ...       ...        ...       ...         ...
# 2043  0.749117  0.407296  0.586983  0.992417   0.230407  0.091122    0.015579
# 2044  0.059204  0.666947  0.911414  0.267003   0.925876  0.154718    0.921622
# 2045  0.900189  0.114500  0.096873  0.754331   0.340017  0.926062    0.198093
# 2046  0.564584  0.941900  0.314116  0.122068   0.634279  0.420092    0.344562
# 2047  0.475866  0.276650  0.632677  0.603490   0.095420  0.628950    0.505561
#
#       bac2_alpha
# 0       0.445824
# 1       0.781097
# 2       0.587653
# 3       0.139222
# 4       0.877884
# ...          ...
# 2043    0.563599
# 2044    0.325455
# 2045    0.900474
# 2046    0.714858
# 2047    0.011056
#
# [2048 rows x 35 columns]

# %% [markdown]
# ### read in the performance metrics of each experiment (RMSE and correlation)

# %%
# %%time

print(os.getcwd())

### RMSE
rmse = pd.read_excel("RMSE_opt.xlsx", header=0)
### std
sdev = pd.read_excel("SDEV_opt.xlsx", header=0)
### correlations
corr = pd.read_excel("CCOEF_opt.xlsx", header=0)
### nstd
nsdev = pd.read_excel("NSDEV_opt.xlsx", header=0)

rmse.columns = rmse.columns.str[0:-5]
sdev.columns = sdev.columns.str[0:-5]
corr.columns = corr.columns.str[0:-6]
nsdev.columns = nsdev.columns.str[0:-6]

print(corr.min(axis=0), corr.max(axis=0))
print(nsdev.min(axis=0), nsdev.max(axis=0))
print(sdev.min(axis=0), sdev.max(axis=0))
print(rmse.min(axis=0), rmse.max(axis=0))
# Out:
# /g/data/vn19/pjb581/WOMBATmid-Optimization/SOTSexps/data
# pco2           -0.981297
# fgco2          -0.964834
# nh4            -0.507887
# no3             0.011368
# sil            -0.020429
# dfe            -0.556241
# poc            -0.295266
# bac            -0.991401
# micro          -0.882875
# meso           -0.783221
# chl_bottle     -0.128661
# chl_mooring    -0.950522
# b1mb2          -0.979188
# D2L300mD2L50   -0.982289
# sum            -4.292709
# dtype: float64 pco2            0.983169
# fgco2           0.956705
# nh4             0.324316
# no3             0.192994
# sil             0.153617
# dfe             0.649449
# poc             0.330019
# bac             0.990106
# micro           0.942064
# meso            0.928367
# chl_bottle      0.129381
# chl_mooring     0.978354
# b1mb2           0.982842
# D2L300mD2L50    0.972104
# sum             6.192771
# dtype: float64
# pco2            6.220892e-02
# fgco2           1.487040e-01
# nh4             6.740048e-06
# no3             1.564713e-01
# sil             1.812641e-01
# dfe             1.788076e-10
# poc             8.485692e-05
# bac             7.222189e-09
# micro           6.405169e-09
# meso            3.018371e-05
# chl_bottle      4.237297e-05
# chl_mooring     3.794887e-05
# b1mb2           2.816713e-01
# D2L300mD2L50    2.292833e-03
# sum             4.123442e+00
# dtype: float64 pco2              3.577991
# fgco2             6.267786
# nh4               5.022128
# no3               1.936238
# sil               2.663640
# dfe               1.780144
# poc               0.767732
# bac               1.031501
# micro             0.363428
# meso              0.314340
# chl_bottle        6.611387
# chl_mooring       3.493601
# b1mb2            22.347118
# D2L300mD2L50    779.460067
# sum             789.465646
# dtype: float64
# pco2            7.695471e-01
# fgco2           1.129989e-01
# nh4             6.480231e-07
# no3             3.692915e-01
# sil             2.209035e-01
# dfe             2.420615e-11
# poc             1.476331e-04
# bac             5.295986e-09
# micro           5.668425e-09
# meso            2.821699e-06
# chl_bottle      5.879563e-06
# chl_mooring     8.851071e-06
# b1mb2           7.966866e-02
# D2L300mD2L50    3.242555e-04
# sum             5.244046e+00
# dtype: float64 pco2             44.261055
# fgco2             4.762838
# nh4               0.482853
# no3               4.569759
# sil               3.246135
# dfe               0.240988
# poc               1.335692
# bac               0.756393
# micro             0.321625
# meso              0.029386
# chl_bottle        0.917379
# chl_mooring       0.814836
# b1mb2             6.320719
# D2L300mD2L50    110.232300
# sum             122.917005
# dtype: float64
# pco2             3.734495
# fgco2            0.425290
# nh4              0.150961
# no3              2.391521
# sil              1.403775
# dfe              0.121764
# poc              1.800535
# bac              0.285407
# micro            0.744147
# meso             0.113919
# chl_bottle       0.216518
# chl_mooring      0.068483
# b1mb2            0.230058
# D2L300mD2L50     0.746355
# sum             24.011669
# dtype: float64 pco2            101.520476
# fgco2            11.596742
# nh4               0.562836
# no3              11.105294
# sil               3.406319
# dfe               0.404897
# poc               2.673508
# bac               1.622992
# micro             1.411810
# meso              0.194657
# chl_bottle        0.947457
# chl_mooring       2.432988
# b1mb2             9.324161
# D2L300mD2L50    335.419200
# sum             394.046858
# dtype: float64
# CPU times: user 2.09 s, sys: 16.1 ms, total: 2.1 s
# Wall time: 2.29 s

# %% [markdown]
# ### create the cost function

# %%
len(rmse)
# Out:
# 2048

# %%
### solve for the observational standard deviation using the normalised standard deviation
obs_std = sdev / nsdev

### calculate the cost function, penalizing experiments where the correlations are very poor
nrmse = (rmse/obs_std)
cost = (1 - corr) * nrmse

targets = rmse.columns
targets
# Out:
# Index(['pco2', 'fgco2', 'nh4', 'no3', 'sil', 'dfe', 'poc', 'bac', 'micro',
#        'meso', 'chl_bottle', 'chl_mooring', 'b1mb2', 'D2L300mD2L50', 'sum'],
#       dtype='object')

# %% [markdown]
# ### check out the distributions of the RMSE, the correlation and the cost function

# %%
fstic = 13
fslab = 15

fig = plt.figure(figsize=(15,15))
gs = GridSpec(3,1)

ax1 = plt.subplot(gs[0,0])
ax2 = plt.subplot(gs[1,0])
ax3 = plt.subplot(gs[2,0])
ax1.spines[['top','right']].set_visible(False)
ax2.spines[['top','right']].set_visible(False)
ax3.spines[['top','right']].set_visible(False)
ax1.tick_params(labelsize=fstic, labelbottom=False)
ax2.tick_params(labelsize=fstic, labelbottom=False)
ax2.tick_params(labelsize=fstic)

box1 = ax1.boxplot(corr, positions=np.arange(0,len(targets),1), widths=0.8, patch_artist=True)
box2 = ax2.boxplot(nrmse, positions=np.arange(0,len(targets),1), widths=0.8, patch_artist=True)
box3 = ax3.boxplot(cost, positions=np.arange(0,len(targets),1), widths=0.8, patch_artist=True)

# Apply colors to each box
for patch in box1['boxes']:
    patch.set_facecolor('w')
for patch in box2['boxes']:
    patch.set_facecolor('w')
for patch in box3['boxes']:
    patch.set_facecolor('w')
for median in box1['medians']:
    median.set(color='firebrick', linewidth=2)
for median in box2['medians']:
    median.set(color='firebrick', linewidth=2)
for median in box3['medians']:
    median.set(color='firebrick', linewidth=2)

ax1.set_xlim(-0.5,len(targets)-1.5)
ax2.set_xlim(-0.5,len(targets)-1.5)
ax3.set_xlim(-0.5,len(targets)-1.5)

#ax2.set_yscale('log')

ax1.set_ylabel("Pearson's correlation", fontsize=fslab)
ax2.set_ylabel("Normalized RMSE", fontsize=fslab)
ax3.set_ylabel("cost function", fontsize=fslab)

ax3.set_xticks(np.arange(0,len(targets[0:-1]),1), targets[0:-1], fontsize=fslab, rotation=90)

plt.subplots_adjust(bottom=0.2)

ax1.set_ylim(-1,1)
ax2.set_ylim(0,10)
ax3.set_ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
os.chdir(wrkdir)
fig.savefig("../figures/sensitivity_analysis_corr_nrmse_costfunction_optimisation.png", dpi=300)
fig.savefig("../figures/sensitivity_analysis_corr_nrmse_costfunction_optimisation.pdf", dpi=300)
fig.savefig("../figures/sensitivity_analysis_corr_nrmse_costfunction_optimisation_transparent.png", dpi=300, transparent=True)

# %% [markdown]
# ## Train a Gaussian Process Regression model on the output

# %% [markdown]
# ### start a dask client cluster

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(n_workers=56, threads_per_worker=1, memory_limit="16GB")
client  = Client(cluster)
client  # shows dashboard link
# Out:
# <Client: 'tcp://127.0.0.1:42895' processes=56 threads=56, memory=834.47 GiB>

# %% [markdown]
# ### train GPR on the normalized RMSE

# %%
# %%time

### format the input data to the GPR model
X.columns = list(range(35))

tarcols = nrmse.columns

Y = np.zeros((2048, len(tarcols)))
for i, target in enumerate(tarcols):
    Y[:,i] = rmse[target]
    # Normalising RMSE values (RMSE - min(RMSE)/max(RMSE) - min(RMSE))
    Y[:,i]=(Y[:,i]-Y[:,i].min())/(Y[:,i].max()-Y[:,i].min())
# Out:
# CPU times: user 4.1 ms, sys: 1.75 ms, total: 5.85 ms
# Wall time: 4.94 ms

# %%
# %%time

targets = ['surface pCO$_2$', \
               'air-sea flux of CO$_2$', \
               'bottle NH$_4$', \
               'bottle NO$_3$', \
               'bottle Si(OH)$_4$', \
               'bottle dFe', \
               'bottle POC', \
               'Spring bacteria', \
               '0-200m mean micro-zoo', \
               '0-200m mean meso-zoo', \
               'bottle chlorophyll', \
               'mooring chlorophyll', \
               'B1 minus B2', \
               'D:L at 300m minus D:L at 50m']
# Out:
# CPU times: user 7 μs, sys: 5 μs, total: 12 μs
# Wall time: 16.7 μs

# %%
n_vars   = len(targets)
n_params = len(X.columns)
N        = len(X)

print(n_vars, n_params, N)
# Out:
# 14 35 2048

# %%
# %%time

from sklearn.model_selection import KFold
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ConstantKernel, Matern, WhiteKernel
from sklearn.exceptions import ConvergenceWarning  # add this near the top
from sklearn.metrics import r2_score
from sklearn.base import clone
from joblib import Parallel, delayed, parallel_backend

import warnings
warnings.filterwarnings('ignore')

n_vars   = len(targets)
n_params = len(X.columns)
N        = len(X)

kf = KFold(n_splits=8, shuffle=True, random_state=42)
splits = list(kf.split(X))  # materialize once so workers can iterate

kernel = (ConstantKernel(1.0, (1e-3, 1e3)) *
          Matern(length_scale=np.ones(n_params),           # 1-D vector (ARD)
                 length_scale_bounds=(1e-3, 5.0), nu=1.5)
          + WhiteKernel(noise_level=1e-6,
                        noise_level_bounds=(1e-9, 1e-2)))

base_gpr = GaussianProcessRegressor(kernel=kernel,
                                    n_restarts_optimizer=5,
                                    random_state=42)

def fit_one_fold(i, f, tr, te):
    warnings.filterwarnings("ignore", category=UserWarning)
    warnings.filterwarnings("ignore", category=RuntimeWarning)
    warnings.filterwarnings("ignore", category=ConvergenceWarning)  # if applicable
    est   = clone(base_gpr)
    est.fit(X.iloc[tr, :], Y[tr, i])
    y_hat = est.predict(X.iloc[te, :])
    r2    = r2_score(Y[te, i], y_hat)
    # return everything needed to assemble safely on the driver
    return (i, f, te, y_hat, Y[te, i], r2)

# run all (target, fold) jobs in parallel
with parallel_backend("dask"): 
    results = Parallel(prefer="processes", verbose=0)(
        delayed(fit_one_fold)(i, f, tr, te)
        for i in range(n_vars)
        for f, (tr, te) in enumerate(splits)
    )

# assemble on the driver (no race conditions)
GPR_score = np.zeros((len(splits), n_vars))
Y_PRED    = np.zeros((N, n_vars))
Y_TRUE    = np.zeros((N, n_vars))

for i, f, te, y_hat, y_true, r2 in results:
    Y_PRED[te, i]      = y_hat
    Y_TRUE[te, i]      = y_true
    GPR_score[f, i]    = r2

# per-target prints and overall R^2
for i in range(n_vars):
    print(i, targets[i], np.round(GPR_score[:, i], 3))

overall_r2 = [r2_score(Y_TRUE[:, i], Y_PRED[:, i]) for i in range(n_vars)]
print("GPR per-target R^2:", np.round(overall_r2, 3))
print("GPR mean R^2:", np.round(np.mean(overall_r2), 3))
# Out:
# 0 surface pCO$_2$ [0.718 0.711 0.505 0.609 0.582 0.664 0.608 0.63 ]
# 1 air-sea flux of CO$_2$ [0.752 0.736 0.591 0.648 0.628 0.709 0.652 0.679]
# 2 bottle NH$_4$ [0.098 0.502 0.549 0.509 0.473 0.415 0.368 0.649]
# 3 bottle NO$_3$ [0.835 0.732 0.785 0.754 0.694 0.745 0.688 0.767]
# 4 bottle Si(OH)$_4$ [0.805 0.772 0.746 0.783 0.808 0.762 0.809 0.774]
# 5 bottle dFe [0.902 0.893 0.885 0.887 0.881 0.872 0.861 0.861]
# 6 bottle POC [0.879 0.834 0.835 0.831 0.895 0.889 0.839 0.874]
# 7 surface bacteria [0.82  0.814 0.79  0.781 0.796 0.757 0.772 0.815]
# 8 0-200m mean micro-zoo [0.868 0.898 0.871 0.868 0.848 0.828 0.841 0.851]
# 9 0-200m mean meso-zoo [0.612 0.597 0.626 0.646 0.636 0.671 0.684 0.682]
# 10 bottle chlorophyll [0.864 0.888 0.886 0.897 0.899 0.879 0.869 0.801]
# 11 mooring chlorophyll [0.894 0.906 0.923 0.916 0.907 0.911 0.899 0.87 ]
# 12 B1 minus B2 [0.653 0.591 0.536 0.702 0.554 0.577 0.633 0.735]
# 13 D:L at 300m minus D:L at 50m [0.924 0.839 0.794 0.642 0.873 0.879 0.904 0.891]
# GPR per-target R^2: [0.631 0.676 0.482 0.754 0.783 0.881 0.859 0.794 0.861 0.65  0.872 0.903
#  0.635 0.856]
# GPR mean R^2: 0.76
# CPU times: user 10min 53s, sys: 7min 50s, total: 18min 43s
# Wall time: 57min 44s

# %%
fig = plt.figure(figsize=(18,14))
plt.rc('font', size=14)    # fontsize of the all text
plt.rc('ytick', labelsize=14)    # fontsize of the tick labels
plt.rc('xtick', labelsize=14)
abc = ['(a) ','(b) ','(c) ',\
       '(d) ','(e) ','(f) ',\
       '(g) ','(h) ','(i) ',\
       '(j) ','(k) ','(l) ',\
       '(m) ','(n) ']

for i in range(len(targets)):
    #ax = fig.add_subplot(2,3,i+1)
    ax = fig.add_subplot(5,3,i+1)
    ax.plot((np.min(Y_TRUE[:,i]),np.max(Y_TRUE[:,i])), (np.min(Y_TRUE[:,i]), np.max(Y_TRUE[:,i])), 'k--')
    ax.scatter(Y_TRUE[:,i],Y_PRED[:,i])
    ax.set_title(abc[i], loc='left')
    ax.text(0.05,0.95, targets[i], va='top', ha='left', transform=ax.transAxes)
    ax.set_title('$R^2$ = '+str(round(r2_score(Y_TRUE[:,i],Y_PRED[:,i]),2)),
               loc='right')
    ax.set_xlabel(r'WOMBAT-mid RMSE')
    ax.set_ylabel('GPR RMSE')
    #ax.set_xlim(0,1)
    #ax.set_ylim(0,1)

plt.tight_layout()
fig.savefig('../figures/sensitivity_analysis_GPRaccuracy_RMSEnormRange_2048_optimisation.png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ### calculate the GPR accuracy at different numbers of experimental samples

# %%
# %%time

import numpy as np
import pandas as pd
import warnings
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ConstantKernel, Matern, WhiteKernel
from sklearn.metrics import r2_score
from sklearn.base import clone
from sklearn.model_selection import KFold
from joblib import Parallel, delayed, parallel_backend

warnings.filterwarnings('ignore')

# --- setup ---
n_vars   = len(targets)
n_params = len(X.columns)
N_total  = len(X)
N_list   = [64, 128, 256, 512, 1024, 2048]   # number of samples to test
n_splits = 8

GPR_score = np.zeros((n_vars, len(N_list), n_splits))

# --- base kernel and model ---
base_kernel = (ConstantKernel(1.0, (1e-3, 1e3)) *
               Matern(length_scale=np.ones(n_params),
                      length_scale_bounds=(1e-3, 5.0), nu=1.5)
               + WhiteKernel(noise_level=1e-6,
                             noise_level_bounds=(1e-9, 1e-2)))

base_gpr = GaussianProcessRegressor(
    kernel=base_kernel,
    n_restarts_optimizer=5,
    random_state=42
)

# --- worker function ---
def fit_one_fold(i, j, f, tr, te, N_sub):
    warnings.filterwarnings("ignore", category=UserWarning)
    warnings.filterwarnings("ignore", category=RuntimeWarning)

    est = clone(base_gpr)
    X_tr, X_te = X.iloc[tr, :], X.iloc[te, :]
    y_tr, y_te = Y[tr, i], Y[te, i]

    est.fit(X_tr, y_tr)
    y_hat = est.predict(X_te)
    r2 = r2_score(y_te, y_hat)
    return (i, j, f, N_sub, r2)
# Out:
# CPU times: user 20.6 ms, sys: 3.66 ms, total: 24.3 ms
# Wall time: 313 ms

# %%
# %%time

# --- main loop (parallelised folds and targets) ---
with parallel_backend("dask"):  # or "loky" if no Dask client
    results = Parallel(prefer="processes", verbose=0)(
        delayed(fit_one_fold)(i, j, f, tr, te, N_sub)
        for j, N_sub in enumerate(N_list)
        for i in range(n_vars)
        for f, (tr, te) in enumerate(
            KFold(n_splits=n_splits, shuffle=True, random_state=42).split(range(N_sub))
        )
    )

# --- assemble results ---
for i, j, f, N_sub, r2 in results:
    GPR_score[i, j, f] = r2

# %%
# --- report results ---
for i in range(n_vars):
    for j, N_sub in enumerate(N_list):
        mean_r2 = np.nanmean(GPR_score[i, j, :])
        print(f"{targets[i]:<25s}  N={N_sub:<5d}  mean R²={mean_r2:.3f}")
# Out:
# surface pCO$_2$            N=64     mean R²=0.000
# surface pCO$_2$            N=128    mean R²=0.000
# surface pCO$_2$            N=256    mean R²=0.000
# surface pCO$_2$            N=512    mean R²=0.000
# surface pCO$_2$            N=1024   mean R²=0.000
# surface pCO$_2$            N=2048   mean R²=0.000
# air-sea flux of CO$_2$     N=64     mean R²=0.000
# air-sea flux of CO$_2$     N=128    mean R²=0.000
# air-sea flux of CO$_2$     N=256    mean R²=0.000
# air-sea flux of CO$_2$     N=512    mean R²=0.000
# air-sea flux of CO$_2$     N=1024   mean R²=0.000
# air-sea flux of CO$_2$     N=2048   mean R²=0.000
# bottle NH$_4$              N=64     mean R²=0.000
# bottle NH$_4$              N=128    mean R²=0.000
# bottle NH$_4$              N=256    mean R²=0.000
# bottle NH$_4$              N=512    mean R²=0.000
# bottle NH$_4$              N=1024   mean R²=0.000
# bottle NH$_4$              N=2048   mean R²=0.000
# bottle NO$_3$              N=64     mean R²=0.000
# bottle NO$_3$              N=128    mean R²=0.000
# bottle NO$_3$              N=256    mean R²=0.000
# bottle NO$_3$              N=512    mean R²=0.000
# bottle NO$_3$              N=1024   mean R²=0.000
# bottle NO$_3$              N=2048   mean R²=0.000
# bottle Si(OH)$_4$          N=64     mean R²=0.000
# bottle Si(OH)$_4$          N=128    mean R²=0.000
# bottle Si(OH)$_4$          N=256    mean R²=0.000
# bottle Si(OH)$_4$          N=512    mean R²=0.000
# bottle Si(OH)$_4$          N=1024   mean R²=0.000
# bottle Si(OH)$_4$          N=2048   mean R²=0.000
# bottle dFe                 N=64     mean R²=0.000
# bottle dFe                 N=128    mean R²=0.000
# bottle dFe                 N=256    mean R²=0.000
# bottle dFe                 N=512    mean R²=0.000
# bottle dFe                 N=1024   mean R²=0.000
# bottle dFe                 N=2048   mean R²=0.000
# bottle POC                 N=64     mean R²=0.000
# bottle POC                 N=128    mean R²=0.000
# bottle POC                 N=256    mean R²=0.000
# bottle POC                 N=512    mean R²=0.000
# bottle POC                 N=1024   mean R²=0.000
# bottle POC                 N=2048   mean R²=0.000
# surface bacteria           N=64     mean R²=0.000
# surface bacteria           N=128    mean R²=0.000
# surface bacteria           N=256    mean R²=0.000
# surface bacteria           N=512    mean R²=0.000
# surface bacteria           N=1024   mean R²=0.000
# surface bacteria           N=2048   mean R²=0.000
# 0-200m mean micro-zoo      N=64     mean R²=0.000
# 0-200m mean micro-zoo      N=128    mean R²=0.000
# 0-200m mean micro-zoo      N=256    mean R²=0.000
# 0-200m mean micro-zoo      N=512    mean R²=0.000
# 0-200m mean micro-zoo      N=1024   mean R²=0.000
# 0-200m mean micro-zoo      N=2048   mean R²=0.000
# 0-200m mean meso-zoo       N=64     mean R²=0.000
# 0-200m mean meso-zoo       N=128    mean R²=0.000
# 0-200m mean meso-zoo       N=256    mean R²=0.000
# 0-200m mean meso-zoo       N=512    mean R²=0.000
# 0-200m mean meso-zoo       N=1024   mean R²=0.000
# 0-200m mean meso-zoo       N=2048   mean R²=0.000
# bottle chlorophyll         N=64     mean R²=0.000
# bottle chlorophyll         N=128    mean R²=0.000
# bottle chlorophyll         N=256    mean R²=0.000
# bottle chlorophyll         N=512    mean R²=0.000
# bottle chlorophyll         N=1024   mean R²=0.000
# bottle chlorophyll         N=2048   mean R²=0.000
# mooring chlorophyll        N=64     mean R²=0.000
# mooring chlorophyll        N=128    mean R²=0.000
# mooring chlorophyll        N=256    mean R²=0.000
# mooring chlorophyll        N=512    mean R²=0.000
# mooring chlorophyll        N=1024   mean R²=0.000
# mooring chlorophyll        N=2048   mean R²=0.000
# B1 minus B2                N=64     mean R²=0.000
# B1 minus B2                N=128    mean R²=0.000
# B1 minus B2                N=256    mean R²=0.000
# B1 minus B2                N=512    mean R²=0.000
# B1 minus B2                N=1024   mean R²=0.000
# B1 minus B2                N=2048   mean R²=0.000
# D:L at 300m minus D:L at 50m  N=64     mean R²=0.000
# D:L at 300m minus D:L at 50m  N=128    mean R²=0.000
# D:L at 300m minus D:L at 50m  N=256    mean R²=0.000
# D:L at 300m minus D:L at 50m  N=512    mean R²=0.000
# D:L at 300m minus D:L at 50m  N=1024   mean R²=0.000
# D:L at 300m minus D:L at 50m  N=2048   mean R²=0.000

# %%
fig = plt.figure(figsize=(15,12))
plt.rc('font', size=12)    # fontsize of the all text
plt.rc('ytick', labelsize=12)    # fontsize of the tick labels
plt.rc('xtick', labelsize=12)
abc = ['(a) ','(b) ','(c) ','(d) ','(e) ','(f) ','(g) ','(h) ','(i) ','(j) ','(k) ']
for i in range(len(targets)):
    axs = fig.add_subplot(4,3,i+1)
    axs.boxplot(GPR_score[i,0:6,:].T)
    axs.set_title(abc[i] + " " + targets[i], loc='left')
    #axs.text(0.5,1.02, targets[i], va='bottom', ha='center', transform=axs.transAxes, rotation=0)
    axs.set_ylabel('$R^2$')
    axs.set_xlabel('Samples')
    axs.set_xticklabels(['64','128','256','512','1024','2048'])
    axs.set_ylim(-1.,1.0)
plt.subplots_adjust(wspace=0.4,hspace=0.4)
plt.tight_layout()
fig.savefig('../figures/sensitivity_analysis_GPRsensitivity_RMSEnormRange_optimisation_2048.png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ### Do Sobol' sensitivity analysis

# %% [markdown]
# #### but only on targets that had an R2 score > 0.6

# %%
# --- report results ---
N_sub = 2048
j = -1
for i in range(n_vars):
    mean_r2 = np.nanmean(GPR_score[i, j, :])
    print(f"{targets[i]:<25s}  N={N_sub:<5d}  mean R²={mean_r2:.3f}")
# Out:
# surface pCO$_2$            N=2048   mean R²=0.000
# air-sea flux of CO$_2$     N=2048   mean R²=0.000
# bottle NH$_4$              N=2048   mean R²=0.000
# bottle NO$_3$              N=2048   mean R²=0.000
# bottle Si(OH)$_4$          N=2048   mean R²=0.000
# bottle dFe                 N=2048   mean R²=0.000
# bottle POC                 N=2048   mean R²=0.000
# surface bacteria           N=2048   mean R²=0.000
# 0-200m mean micro-zoo      N=2048   mean R²=0.000
# 0-200m mean meso-zoo       N=2048   mean R²=0.000
# bottle chlorophyll         N=2048   mean R²=0.000
# mooring chlorophyll        N=2048   mean R²=0.000
# B1 minus B2                N=2048   mean R²=0.000
# D:L at 300m minus D:L at 50m  N=2048   mean R²=0.000

# %%
# %%time

from SALib.sample import saltelli

# Define the problem with 100 parameters
problem = {
    'num_vars': len(X.columns),
    'names': [f'P{i+1}' for i in range(len(X.columns))],
    'bounds': [[0, 1]] * len(X.columns)
}

# Generate the Saltelli sampling (1024 base samples, including 2nd-order terms)
param_values = saltelli.sample(problem, 2048, calc_second_order=True)

print(param_values.shape)
print("Max of first parameter:", max(param_values[:, 0]))
# Out:
# (147456, 35)
# Max of first parameter: 0.999755859375
# CPU times: user 2.25 s, sys: 87.9 ms, total: 2.34 s
# Wall time: 2.32 s

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(n_workers=28, threads_per_worker=4, memory_limit="32GB")
client  = Client(cluster)
client  # shows dashboard link
# Out:
# <Client: 'tcp://127.0.0.1:45941' processes=28 threads=112, memory=834.47 GiB>

# %%
# %%time

def sobol_for_target(i):
    """Train GPR for one target variable and compute Sobol indices."""
    import warnings
    warnings.filterwarnings("ignore")
    y = Y[:, i]
    model = gaussian_process.GaussianProcessRegressor(kernel=base_kernel, random_state=42)
    model.fit(X, y)
    y_hat = model.predict(param_values)
    Si = sobol.analyze(problem, y_hat, parallel=False, print_to_console=False)
    return (i, Si['S1'], Si['ST'], Si['S2'])

# --- parallel execution ---
with parallel_backend("dask"):
    results_sobol = Parallel(prefer="processes", verbose=10)(
        delayed(sobol_for_target)(i) for i in range(n_vars)
    )
# Out:
# [Parallel(n_jobs=-1)]: Using backend DaskDistributedBackend with 112 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  14 | elapsed:  4.8min remaining: 17.6min
# [Parallel(n_jobs=-1)]: Done   5 out of  14 | elapsed:  4.9min remaining:  8.8min
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:  5.6min remaining:  5.6min
# [Parallel(n_jobs=-1)]: Done   9 out of  14 | elapsed:  7.3min remaining:  4.1min
# [Parallel(n_jobs=-1)]: Done  11 out of  14 | elapsed:  8.7min remaining:  2.4min
# CPU times: user 3min 8s, sys: 2min 11s, total: 5min 19s
# Wall time: 9min 51s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:  9.9min finished

# %%
# --- gather results ---
s1 = np.zeros((n_vars, n_params))
st = np.zeros((n_vars, n_params))
s2 = np.zeros((n_vars, n_params, n_params))

for i, S1, ST, S2 in results_sobol:
    s1[i, :] = S1
    st[i, :] = ST
    s2[i, :, :] = S2
    print(f"Target {i}: mean ST = {np.nanmean(ST):.3f}")

print("\nDone computing Sobol indices for all targets.")
# Out:
# Target 0: mean ST = 0.052
# Target 1: mean ST = 0.050
# Target 2: mean ST = 0.049
# Target 3: mean ST = 0.045
# Target 4: mean ST = 0.035
# Target 5: mean ST = 0.036
# Target 6: mean ST = 0.035
# Target 7: mean ST = 0.033
# Target 8: mean ST = 0.034
# Target 9: mean ST = 0.037
# Target 10: mean ST = 0.036
# Target 11: mean ST = 0.036
# Target 12: mean ST = 0.043
# Target 13: mean ST = 0.052
#
# Done computing Sobol indices for all targets.

# %%
df = pd.DataFrame(data=st,
                    index=targets,
                    columns=problem['names'])
df_t = df.T
df_t = (df_t-df_t.min())/(df_t.max()-df_t.min())
df = df_t.T
df
# Out:
#                                     P1        P2        P3        P4  \
# surface pCO$_2$               0.077937  0.475412  0.051223  0.000620
# air-sea flux of CO$_2$        0.072665  0.483571  0.047059  0.000662
# bottle NH$_4$                 0.001778  0.343274  0.000348  0.001211
# bottle NO$_3$                 0.031762  0.358282  0.019236  0.005294
# bottle Si(OH)$_4$             0.000669  0.003771  0.000266  0.031922
# bottle dFe                    0.002081  0.023713  0.000764  0.000720
# bottle POC                    0.000724  0.008274  0.000805  0.000432
# Spring bacteria               0.069091  0.399264  0.020203  0.003518
# 0-200m mean micro-zoo         0.086934  0.652617  0.029776  0.001802
# 0-200m mean meso-zoo          0.027111  0.261294  0.010398  0.001181
# bottle chlorophyll            0.004370  0.221611  0.011793  0.000401
# mooring chlorophyll           0.011655  0.322186  0.013322  0.000079
# B1 minus B2                   0.001892  0.046903  0.003309  0.000736
# D:L at 300m minus D:L at 50m  0.000620  0.031835  0.000597  0.000177
#
#                                     P5        P6        P7        P8  \
# surface pCO$_2$               0.044998  0.002687  0.009220  0.001424
# air-sea flux of CO$_2$        0.035879  0.002153  0.009961  0.000925
# bottle NH$_4$                 0.001040  0.008786  0.000023  0.001288
# bottle NO$_3$                 0.071548  0.039526  0.000657  0.003218
# bottle Si(OH)$_4$             0.145022  0.000230  0.008722  0.005248
# bottle dFe                    0.002562  0.021762  0.002062  0.002093
# bottle POC                    0.000000  0.000705  0.000300  0.022505
# Spring bacteria               0.007699  0.005120  0.001223  0.023709
# 0-200m mean micro-zoo         0.001157  0.084392  0.018717  0.182761
# 0-200m mean meso-zoo          0.003516  0.017211  0.000000  0.186761
# bottle chlorophyll            0.000625  0.053765  1.000000  0.086647
# mooring chlorophyll           0.000308  0.043763  1.000000  0.175098
# B1 minus B2                   0.005593  0.000653  0.001041  0.129155
# D:L at 300m minus D:L at 50m  0.001166  0.000979  0.000138  0.775234
#
#                                     P9       P10  ...       P26           P27  \
# surface pCO$_2$               0.000000  0.004922  ...  0.014107  5.304578e-03
# air-sea flux of CO$_2$        0.000000  0.006764  ...  0.010864  5.840851e-03
# bottle NH$_4$                 0.000352  0.001152  ...  0.000288  8.182265e-05
# bottle NO$_3$                 0.005622  0.011877  ...  0.024463  7.197859e-04
# bottle Si(OH)$_4$             0.003617  0.052251  ...  0.000895  7.664207e-03
# bottle dFe                    0.002317  0.001551  ...  1.000000  9.805397e-07
# bottle POC                    0.000485  0.000649  ...  0.006388  7.293808e-04
# Spring bacteria               0.000393  0.000449  ...  0.019106  4.293978e-03
# 0-200m mean micro-zoo         0.000836  0.001930  ...  0.053443  9.354561e-04
# 0-200m mean meso-zoo          0.001059  0.001865  ...  0.008674  9.457905e-03
# bottle chlorophyll            0.000486  0.001672  ...  0.017062  6.775579e-04
# mooring chlorophyll           0.000301  0.000630  ...  0.025180  6.766155e-04
# B1 minus B2                   0.000282  0.011400  ...  0.000000  1.443018e-02
# D:L at 300m minus D:L at 50m  0.000296  0.007181  ...  0.000803  4.610770e-04
#
#                                    P28       P29       P30       P31  \
# surface pCO$_2$               0.000343  0.001847  0.341707  0.000141
# air-sea flux of CO$_2$        0.000435  0.001874  0.308936  0.000178
# bottle NH$_4$                 1.000000  0.000000  0.028793  0.010836
# bottle NO$_3$                 0.000000  0.001396  0.346881  0.213622
# bottle Si(OH)$_4$             0.000835  0.000341  0.000000  0.001076
# bottle dFe                    0.000363  0.001412  0.042130  0.000098
# bottle POC                    0.000257  0.000556  0.000091  0.000135
# Spring bacteria               0.000480  0.000690  0.062682  0.000487
# 0-200m mean micro-zoo         0.000392  0.001201  0.002890  0.000569
# 0-200m mean meso-zoo          0.003680  0.000201  0.002482  0.001476
# bottle chlorophyll            0.000258  0.000000  0.002916  0.000566
# mooring chlorophyll           0.000177  0.000022  0.002258  0.000124
# B1 minus B2                   0.001189  0.000718  0.000122  0.001363
# D:L at 300m minus D:L at 50m  0.003357  0.000000  0.000394  0.000231
#
#                                    P32       P33       P34       P35
# surface pCO$_2$               0.008453  0.063735  0.017522  1.000000
# air-sea flux of CO$_2$        0.006370  0.074600  0.017306  1.000000
# bottle NH$_4$                 0.029048  0.002746  0.000384  0.223123
# bottle NO$_3$                 0.024058  0.194649  0.064420  1.000000
# bottle Si(OH)$_4$             0.003532  0.007392  0.000609  0.001142
# bottle dFe                    0.162800  0.674846  0.020290  0.332087
# bottle POC                    0.227180  1.000000  0.171863  0.000135
# Spring bacteria               0.013075  1.000000  0.064757  0.312713
# 0-200m mean micro-zoo         0.030187  0.066170  0.014891  0.014099
# 0-200m mean meso-zoo          0.078443  0.387142  0.077420  0.006974
# bottle chlorophyll            0.006836  0.038086  0.002472  0.013828
# mooring chlorophyll           0.005016  0.040368  0.002059  0.012030
# B1 minus B2                   1.000000  0.760320  0.019618  0.000474
# D:L at 300m minus D:L at 50m  0.340766  1.000000  0.145107  0.000502
#
# [14 rows x 35 columns]

# %%
tmp = pd.read_excel("apriori_parameter_ranges.xlsx", sheet_name="parameter_ranges")
tmp = tmp[tmp["optimisation?"]==1]
tmp = tmp.drop(["units", "References", "sensitivity analysis?", "optimisation?", "parameter number"], axis=1)
tmp = tmp.set_index("WOMBAT-mid")
param_names = tmp.index
np.array(list(param_names))
# Out:
# array(['alphabio_phy', 'abioa_phy', 'bbioa_phy', 'alphabio_dia',
#        'abioa_dia', 'phykf', 'phymaxqc', 'phylmor', 'diakf', 'diaVmaxs',
#        'dialmor', 'overflow', 'zooCassim', 'zooFeingest', 'zooFeassim',
#        'zooepsphy', 'zprefdet', 'zoolmor', 'mprefdia', 'mprefdet',
#        'bdetphi', 'diarad0', 'phybiot', 'diabiot', 'dfefloor',
#        'kcoag_dfe', 'bsi_kbac', 'aoalmor', 'Hox_fac', 'Oox_fac',
#        'Nox_fac', 'bac1_kpoc', 'bac1lmor', 'bac1_alpha', 'bac2_alpha'],
#       dtype='<U12')

# %%
fig = plt.figure(figsize=(12,20))
gs = GridSpec(1,1)

ax = plt.subplot(gs[0])
ax = sns.heatmap(df.T,cmap="Reds",linewidths=.5, annot=True,fmt=".2f")
plt.xticks(rotation='horizontal')
ax.set_xticklabels(targets, rotation=90, fontsize=14, ha='right')
ax.set_yticklabels(np.array(list(param_names)), fontsize=14, ha='right')
plt.yticks(rotation='horizontal')
plt.tight_layout()

# %%
os.getcwd()
fig.savefig('../figures/sensitivity_analysis_heatmap_35parameters_2048exps.png', dpi=300,bbox_inches='tight')

# %%
var_names = [
    'Surface pCO$_2$', 
    'air-sea flux of CO$_{2}$ ', 
    'Bottle NH$_4$', 
    'Bottle NO$_3$',
    'Bottle Si(OH)$_4$', 
    'Bottle dFe', 
    'Bottle POC', 
    'Spring bacteria',
    'MAREDAT mean Microzoo 0-200m',
    'MAREDAT mean Mesozoo 0-200m',
    'Bottle chlorophyll',
    'Mooring chlorophyll',
    'B1 minus B2',
    'D:L at 300m minus D:L at 50m'
]

# First dataset processing
df1 = pd.DataFrame(data=s1, index=var_names, columns=problem['names'])
df_t1 = df1.T
#df_t1 = (df_t1 - df_t1.min()) / (df_t1.max() - df_t1.min())
df1 = df_t1.T

# Second dataset processing
df2 = pd.DataFrame(data=(st - s1), index=var_names, columns=problem['names'])
df_t2 = df2.T
#df_t2 = (df_t2 - df_t2.min()) / (df_t2.max() - df_t2.min())
df2 = df_t2.T

# Create subplots
fig, axes = plt.subplots(2, 1, figsize=(40, 15))

# Plot first heatmap (subplot a)
hmap1 = sns.heatmap(df1, cmap="Reds", linewidths=0.5, annot=True, fmt=".2f", ax=axes[0], annot_kws={"size": 18})
#axes[0].set_xticklabels(param_names, rotation=90, fontsize=18, ha='right')
axes[0].set_title('a) First order', fontsize=25)
axes[0].set_yticklabels(axes[0].get_yticklabels(), fontsize=18)
axes[0].set_xticklabels(axes[0].get_xticklabels(), fontsize=24)
axes[0].tick_params(labelbottom=False)

# Plot second heatmap (subplot b)
hmap2 = sns.heatmap(df2, cmap="Reds", linewidths=0.5, annot=True, fmt=".2f", ax=axes[1], annot_kws={"size": 18})
axes[1].set_xticklabels(param_names, rotation=90, fontsize=18, ha='right')
axes[1].set_title('b) Higher order', fontsize=25)
axes[1].set_yticklabels(axes[1].get_yticklabels(), fontsize=18)
axes[1].set_xticklabels(axes[1].get_xticklabels(), fontsize=24)

cbar1 = hmap1.collections[0].colorbar
cbar2 = hmap2.collections[0].colorbar
cbar1.set_label('Sensitivity', fontsize=24)
cbar1.ax.tick_params(labelsize=18)
cbar2.set_label('Sensitivity', fontsize=24)
cbar2.ax.tick_params(labelsize=18)

# Adjust layout
plt.tight_layout()
fig.savefig('../figures/sensitivity_analysis_SAresult_RMSEnormRange_2048exps_optimisation.png', dpi=300, bbox_inches='tight')
fig.savefig('../figures/sensitivity_analysis_SAresult_RMSEnormRange_2048exps_optimisation.pdf', dpi=300, bbox_inches='tight')
