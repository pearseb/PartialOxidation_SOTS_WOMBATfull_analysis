# %% [markdown]
# # Generate 1024 parameter sets to effectively sample the parameter space of WOMBAT-mid run in RYF of ACCESS-OM2

# %% [markdown]
# ### imports

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sci
from scipy.stats import qmc

wrkdir = "/g/data/vn19/pjb581/SOTS-Optimization/WOMBATfull/data"

# print versions of packages
print("python version =",sys.version[:5])
print("numpy version =", np.__version__)
print("pandas version =", pd.__version__)
print("scipy version =", sci.__version__)
print("matplotlib version =", sys.modules[plt.__package__].__version__)

os.chdir(wrkdir)
os.listdir()
# Out:
# python version = 3.10.
# numpy version = 1.26.4
# pandas version = 2.3.3
# scipy version = 1.15.3
# matplotlib version = 3.10.6
# ['BIAS.xlsx',
#  'NSDEV.xlsx',
#  'parameter_ranges.xlsx',
#  'apriori_parameter_ranges.xlsx',
#  'SDEV.xlsx',
#  'NRMSE.xlsx',
#  'CCOEF.xlsx',
#  'parameter_sets_1024.xlsx',
#  'parameter_sets_2048.txt',
#  'parameter_sets_1024.txt',
#  'parameter_norm_2048.xlsx',
#  'RMSE.xlsx',
#  'parameter_sets_2048.xlsx',
#  'parameter_sets.xlsx',
#  'parameter_norm_1024.txt',
#  'parameter_sets.txt',
#  'parameter_norm_1024.xlsx',
#  'parameter_norm_2048.txt']

# %% [markdown]
# ### find the Sobol parameter sequence for the complete parameter set

# %%
df = pd.read_excel("apriori_parameter_ranges.xlsx", sheet_name="parameter_ranges")
df
# Out:
#         WOMBAT-mid       min       max                       units  \
# 0     alphabio_phy         1         4  (w/m2)-1 (mg Chl / mg C)-1
# 1        abioa_phy  0.000003  0.000017                          /s
# 2        bbioa_phy      1.04      1.08                        none
# 3     alphabio_dia         1         4  (w/m2)-1 (mg Chl / mg C)-1
# 4     alphabio_tri      0.25         2  (w/m2)-1 (mg Chl / mg C)-1
# ..             ...       ...       ...                         ...
# 171      bac3_fele       0.1       0.1               dimensionless
# 172  bac3_nosc_opt       0.5       0.5               dimensionless
# 173  bac3_nosc_sig         1         1               dimensionless
# 174          aoxkn      0.45      0.45               mmol NH4 / m3
# 175       aoxmumax    0.0025    0.0025           mmol C / m3 / day
#
#                                             References  sensitivity analysis?  \
# 0                               MacIntyre et al., 2002                      1
# 1          Anderson et al., 2021 Nature Communications                      1
# 2          Anderson et al., 2021 Nature Communications                      1
# 3    MacIntyre et al., 2002; Edwards et al., 2015; ...                      1
# 4    Masotti et al., 2007 Marine Ecology Progress S...                      1
# ..                                                 ...                    ...
# 171                            Zakem et al., 2020 ISME                      0
# 172                                                NaN                      0
# 173                                                NaN                      0
# 174                                 Awata et al., 2013                      0
# 175                                 Lotti et al., 2014                      0
#
#      optimisation?  parameter number  optim number
# 0                1                 1             1
# 1                1                 2             2
# 2                1                 3             3
# 3                1                 4             4
# 4                0                 5             4
# ..             ...               ...           ...
# 171              0               100            35
# 172              0               100            35
# 173              0               100            35
# 174              0               100            35
# 175              0               100            35
#
# [176 rows x 9 columns]

# %% [markdown]
# ### select only the parameters we are going to vary and collect information

# %%
param_ranges = df[df["optimisation?"]==1]

param_ranges = param_ranges.drop(["units", "References", "sensitivity analysis?", "optimisation?", "parameter number"], axis=1)
param_ranges = param_ranges.set_index("WOMBAT-mid")
param_ranges
# Out:
#                              min                 max  optim number
# WOMBAT-mid
# alphabio_phy                   1                   4             1
# abioa_phy     0.0000028935185185  0.0000173611111111             2
# bbioa_phy                   1.04  1.0800000000000001             3
# alphabio_dia                   1                   4             4
# abioa_dia      0.000005787037037  0.0000173611111111             5
# phykf                        0.1                   3             6
# phymaxqc                    0.01                0.08             7
# phylmor                       -4                  -1             8
# diakf                        0.1                   3             9
# diaVmaxs      0.0000003472222222  0.0000069444444444            10
# dialmor                       -4                  -1            11
# overflow                     0.1                 0.9            12
# zooCassim                   0.15                 0.5            13
# zooFeingest                 0.05                 0.5            14
# zooFeassim                   0.5                0.95            15
# zooepsphy     0.0000005787037037   0.000005787037037            16
# zprefdet                     0.5                   1            17
# zoolmor                       -4                  -1            18
# mprefdia                     0.5                   1            19
# mprefdet                     0.5                   1            20
# bdetphi                      0.5                0.99            21
# diarad0                       20                 200            22
# phybiot                      0.1                   2            23
# diabiot                      0.1                   2            24
# dfefloor                   0.001                0.05            25
# kcoag_dfe                     -9                  -4            26
# bsi_kbac                    0.01                   1            27
# aoalmor                       -4                  -1            28
# Hox_fac                      0.1                   1            29
# Oox_fac                        1                   2            30
# Nox_fac                      0.1                   1            31
# bac1_kpoc                    0.1                  10            32
# bac1lmor                      -4                  -1            33
# bac1_alpha                  0.05                0.95            34
# bac2_alpha                  0.05                0.95            35

# %%
pd.set_option("display.precision", 16)
param_ranges.loc['abioa_phy']
# Out:
# min             0.0000028935185185
# max             0.0000173611111111
# optim number                     2
# Name: abioa_phy, dtype: object

# %% [markdown]
# ### Create a normalized sobol sample

# %%
dim = len(param_ranges)
exps = 2048
sampler = qmc.Sobol(d=dim, scramble=True, seed=10)
sample_qmc = sampler.random(n=exps)  #here, n=256=2^8 
sample_qmc.shape
# Out:
# (2048, 35)

# %% [markdown]
# ### Create the parameter sets for our sensitivity experiments

# %%
param_sets = np.zeros((exps,dim))

# Loop over variables correctly
for ii, var in enumerate(param_ranges.index):
    param_sets[:, ii] = (
        param_ranges.loc[var, "min"]
        + (param_ranges.loc[var, "max"] - param_ranges.loc[var, "min"])
        * sample_qmc[:, ii]
    )

names = param_ranges.index
df_exps = pd.DataFrame(param_sets, columns=names)
df_norm = pd.DataFrame(sample_qmc, columns=names)
df_norm
# Out:
# WOMBAT-mid        alphabio_phy           abioa_phy           bbioa_phy  \
# 0           0.9870995162054896  0.8023925330489874  0.0114757269620895
# 1           0.2418825458735228  0.1587966233491898  0.5723490538075566
# 2           0.4905765056610107  0.6605776734650135  0.4342632647603750
# 3           0.7374402554705739  0.3001234401017427  0.9975360585376620
# 4           0.5716488128527999  0.5975599028170109  0.6464223228394985
# ...                        ...                 ...                 ...
# 2043        0.5718227513134480  0.2975849732756615  0.3883295953273773
# 2044        0.7382435929030180  0.5938078891485929  0.2238308554515243
# 2045        0.4907688079401851  0.4914049282670021  0.6610355321317911
# 2046        0.2415987225249410  0.9861115030944347  0.3304295996204019
# 2047        0.9864487349987030  0.1005659196525812  0.7690800242125988
#
# WOMBAT-mid        alphabio_dia           abioa_dia               phykf  \
# 0           0.1757747754454613  0.8299645446240902  0.0203756187111139
# 1           0.7671993039548397  0.2638950832188129  0.7624534470960498
# 2           0.4417648948729038  0.1576750036329031  0.5617152946069837
# 3           0.5998419523239136  0.7487076055258512  0.2882673032581806
# 2045        0.7543307943269610  0.3400170402601361  0.9260618630796671
# 2046        0.1220676777884364  0.6342789810150862  0.4200924374163151
# 2047        0.6034899568185210  0.0954202106222510  0.6289501124992967
#
# WOMBAT-mid          bac1_alpha          bac2_alpha
# 0           0.5935327904298902  0.4458240028470755
# 1           0.3072600280866027  0.7810969855636358
# 2           0.1412903498858213  0.5876533323898911
# 3           0.9900330714881420  0.1392221236601472
# 4           0.0835168696939945  0.8778844196349382
# ...                        ...                 ...
# 2043        0.0155785121023655  0.5635988628491759
# 2044        0.9216216914355755  0.3254550062119961
# 2045        0.1980925928801298  0.9004741720855236
# 2046        0.3445624923333526  0.7148582665249705
# 2047        0.5055605964735150  0.0110558746382594
#
# [2048 rows x 35 columns]

# %% [markdown]
# ### Save the parameter sets to an excel spreadsheet

# %%
os.chdir(wrkdir)
df_exps.to_excel('/g/data/vn19/pjb581/WOMBATmid-Optimization/SOTSexps/data/optimisation_sets_2048.xlsx')
df_exps.to_csv('/g/data/vn19/pjb581/WOMBATmid-Optimization/SOTSexps/data/optimisation_sets_2048.txt', sep=' ')
df_norm.to_excel('/g/data/vn19/pjb581/WOMBATmid-Optimization/SOTSexps/data/optimisation_norm_2048.xlsx')
df_norm.to_csv('/g/data/vn19/pjb581/WOMBATmid-Optimization/SOTSexps/data/optimisation_norm_2048.txt', sep=' ')

# %%
os.getcwd()
# Out:
# '/g/data/vn19/pjb581/WOMBATmid-Optimization/data'

# %%
df_exps
# Out:
# WOMBAT-mid        alphabio_phy           abioa_phy           bbioa_phy  \
# 0           3.9612985486164689  0.0000145022067860  1.0404590290784836
# 1           1.7256476376205683  0.0000051909233702  1.0628939621523024
# 2           2.4717295169830322  0.0000124504871740  1.0573705305904151
# 3           3.2123207664117217  0.0000072355821774  1.0799014423415065
# 4           2.7149464385583997  0.0000115387717421  1.0658568929135801
# ...                        ...                 ...                 ...
# 2043        2.7154682539403439  0.0000071988566735  1.0555331838130952
# 2044        3.2147307787090540  0.0000114844891370  1.0489532342180610
# 2045        2.4723064238205552  0.0000100029648187  1.0664414212852718
# 2046        1.7247961675748229  0.0000171601779962  1.0532171839848161
# 2047        3.9593462049961090  0.0000043484652728  1.0707632009685040
#
# WOMBAT-mid        alphabio_dia           abioa_dia               phykf  \
# 0           1.5273243263363838  0.0000153931081554  0.1590892942622304
# 1           3.3015979118645191  0.0000088413782780  2.3111149965785445
# 2           2.3252946846187115  0.0000076119792087  1.7289743543602527
# 3           2.7995258569717407  0.0000144526343232  0.9359751794487238
# 4           3.2300946032628417  0.0000125578223486  0.5323205994442105
# ...                        ...                 ...                 ...
# 2043        3.9925199812278152  0.0000076481800082  2.4190476794727145
# 2044        3.5385081022977829  0.0000059345657657  1.9502672488801183
# 2045        1.5627834759652615  0.0000125103449790  1.2477713851258159
# 2046        2.5640232898294926  0.0000173340403772  0.5721845366060734
# 2047        2.2882448062300682  0.0000105145416348  2.8149348025210204
#
# WOMBAT-mid            phymaxqc             phylmor               diakf  \
# 0           0.0120036148745567 -3.0827280972152948  2.1829259639605878
# 1           0.0777161687053740 -1.8180040176957846  0.7377511415630579
# 2           0.0282399189006537 -1.6813914906233549  1.5250546514987946
# 3           0.0587430506944656 -3.4177834112197161  2.8456235559657217
