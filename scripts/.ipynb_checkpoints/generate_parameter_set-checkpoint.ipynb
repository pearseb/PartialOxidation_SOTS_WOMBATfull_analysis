# %% [markdown]
# # Generate 1024 parameter sets to effectively sample the parameter space of WOMBAT-mid run in RYF of ACCESS-OM2

# %% [markdown]
# ### imports

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sci
from scipy.stats import qmc

wrkdir = "/g/data/vn19/pjb581/SOTS-Optimization/WOMBATfull/data"

# print versions of packages
print("python version =",sys.version[:5])
print("numpy version =", np.__version__)
print("pandas version =", pd.__version__)
print("scipy version =", sci.__version__)
print("matplotlib version =", sys.modules[plt.__package__].__version__)

os.chdir(wrkdir)
os.listdir()
# Out:
# python version = 3.10.
# numpy version = 1.26.4
# pandas version = 2.3.3
# scipy version = 1.15.3
# matplotlib version = 3.10.6
# ['BIAS_optimal.xlsx',
#  'BIAS.xlsx',
#  'GPR_pco2_cost.joblib',
#  'GPR_pco2_rmse.joblib',
#  'NSDEV.xlsx',
#  'NRMSE_optimal.xlsx',
#  'parameter_ranges.xlsx',
#  'GPR_chl_bottle_corr.joblib',
#  'GPR_bac_corr.joblib',
#  'parameter_norm_optimal100_2.txt',
#  'parameter_sets_optimal100_2.txt',
#  'GPR_micro_corr.joblib',
#  'SDEV_opt.xlsx',
#  'optimisation_norm_2048.txt',
#  'GPR_micro_cost.joblib',
#  'GPR_chl_bottle_cost.joblib',
#  'parameter_NRMSEpredicted_optimal100_2.txt',
#  'apriori_parameter_ranges.xlsx',
#  'GPR_fgco2_rmse.joblib',
#  'parameter_norm_optimal100_3.txt',
#  'CCOEF_opt.xlsx',
#  'GPR_no3.joblib',
#  'GPR_poc_cost.joblib',
#  'GPR_sil.joblib',
#  'GPR_sil_cost.joblib',
#  'GPR_fgco2.joblib',
#  'SDEV.xlsx',
#  'GPR_pco2.joblib',
#  'mcmc_wombat_mid_26params_1M_rmse_withSIL.h5',
#  'CCOEF_optimal.xlsx',
#  'mcmc_wombat_mid_26params_1M_rmse.h5',
#  'GPR_sil_rmse.joblib',
#  'GPR_fgco2_cost.joblib',
#  'NSDEV_optimal.xlsx',
#  'GPR_chl_bottle_rmse.joblib',
#  'GPR_b1mb2.joblib',
#  'NRMSE.xlsx',
#  'CCOEF.xlsx',
#  'GPR_nh4_corr.joblib',
#  'GPR_chl_mooring_corr.joblib',
#  'parameter_sets_1024.xlsx',
#  'GPR_b1mb2_rmse.joblib',
#  'poc_attenuation_fits_100exp_optimal.nc',
#  'GPR_nh4_rmse.joblib',
#  'GPR_meso_corr.joblib',
#  'GPR_poc_corr.joblib',
#  'GPR_no3_rmse.joblib',
#  'poc_attenuation_fits_300exp_optimal.nc',
#  'GPR_pco2_corr.joblib',
#  'parameter_NRMSEpredicted_optimal100.txt',
#  'GPR_micro_rmse.joblib',
#  'GPR_poc_rmse.joblib',
#  'GPR_bac_cost.joblib',
#  'optimisation_sets_2048.txt',
#  'GPR_D2L300mD2L50.joblib',
#  'parameter_sets_2048.txt',
#  'poc_attenuation_fits_200exp_optimal.nc',
#  'parameter_sets_4MF.txt',
#  'output',
#  'SDEV_optimal.xlsx',
#  'mcmc_wombat_mid_26params_1M_rmse_all_P33safe.h5',
#  'mcmc_wombat_mid_26params_2026Jun22.h5',
#  'GPR_dfe_corr.joblib',
#  'GPR_sil_corr.joblib',
#  'GPR_dfe_rmse.joblib',
#  'optimisation_norm_2048.xlsx',
#  'GPR_D2L300mD2L50_cost.joblib',
#  'GPR_b1mb2_cost.joblib',
#  'GPR_D2L300mD2L50_corr.joblib',
#  'GPR_fgco2_corr.joblib',
#  'GPR_chl_mooring_rmse.joblib',
#  'GPR_meso_rmse.joblib',
#  'parameter_sets_1024.txt',
#  'RMSE_optimal.xlsx',
#  'parameter_norm_2048.xlsx',
#  'RMSE_opt.xlsx',
#  'NRMSE_opt.xlsx',
#  'GPR_chl_mooring_cost.joblib',
#  'GPR_D2L300mD2L50_rmse.joblib',
#  'RMSE.xlsx',
#  'apriori_parameter_ranges_SOTSexps.xlsx',
#  'mcmc_wombat_mid_26params_1M_rmse_all.h5',
#  'ferret.jnl',
#  'poc_attenuation_fits_400exp_optimal.nc',
#  'GPR_meso_cost.joblib',
#  'mcmc_wombat_mid_26params_1M.h5',
#  'GPR_nh4.joblib',
#  'parameter_sets_optimal100.txt',
#  'parameter_sets_optimal100_3.txt',
#  'GPR_b1mb2_corr.joblib',
#  'GPR_dfe_cost.joblib',
#  'GPR_bac_rmse.joblib',
#  'parameter_sets_2048.xlsx',
#  'parameter_sets.xlsx',
#  'parameter_norm_1024.txt',
#  'parameter_sets.txt',
#  'parameter_norm_optimal100.txt',
#  'GPR_nh4_cost.joblib',
#  'GPR_chl_bottle.joblib',
#  'parameter_norm_1024.xlsx',
#  'parameter_norm_2048.txt',
#  'NSDEV_opt.xlsx',
#  'GPR_no3_corr.joblib',
#  'BIAS_opt.xlsx',
#  'GPR_poc.joblib',
#  'mcmc_wombat_mid_26params_2026Jun20.h5',
#  'optimisation_sets_2048.xlsx',
#  'GPR_no3_cost.joblib',
#  'poc_attenuation_fits_2048exp_optimisation.nc',
#  'poc_attenuation_fits_2048exp.nc',
#  'GPR_chl_mooring.joblib',
#  'GPR_dfe.joblib']

# %% [markdown]
# ### find the Sobol parameter sequence for the complete parameter set

# %%
df = pd.read_excel("apriori_parameter_ranges_SOTSexps.xlsx", sheet_name="parameter_ranges")
df
# Out:
#       WOMBAT-full       min       max                       units  \
# 0    alphabio_phy         1         4  (w/m2)-1 (mg Chl / mg C)-1
# 1       abioa_phy  0.000003  0.000017                          /s
# 2       bbioa_phy      1.04      1.08                        none
# 3    alphabio_dia         1         4  (w/m2)-1 (mg Chl / mg C)-1
# 4    alphabio_tri      0.25         2  (w/m2)-1 (mg Chl / mg C)-1
# ..            ...       ...       ...                         ...
# 163      bac_C2Fe   1/40e-6   1/40e-6              mol C / mol Fe
# 164       baclmor        -4        -1                          /s
# 165       bacqmor       0.0  0.000003       (mmol C / m3)-1 day-1
# 166      aox_knh4      0.45      0.45               mmol NH4 / m3
# 167     aox_mumax    0.0025    0.0025           mmol C / m3 / day
#
#                                             References  sensitivity analysis?  \
# 0                               MacIntyre et al., 2002                      1
# 1          Anderson et al., 2021 Nature Communications                      1
# 2          Anderson et al., 2021 Nature Communications                      1
# 3    MacIntyre et al., 2002; Edwards et al., 2015; ...                      1
# 4    Masotti et al., 2007 Marine Ecology Progress S...                      1
# ..                                                 ...                    ...
# 163                               Fourquez et al. 2020                      0
# 164                                Baker & Geider 2021                      1
# 165                                        Suttle 1994                      1
# 166                                 Awata et al., 2013                      0
# 167                                 Lotti et al., 2014                      0
#
#      optimisation?  parameter number  optim number
# 0                1                 1             1
# 1                1                 2             2
# 2                1                 3             3
# 3                1                 4             4
# 4                0                 5             4
# ..             ...               ...           ...
# 163              0               103            34
# 164              1               104            35
# 165              0               105            35
# 166              0               105            35
# 167              0               105            35
#
# [168 rows x 9 columns]

# %% [markdown]
# ### select only the parameters we are going to vary and collect information

# %%
param_ranges = df[df["sensitivity analysis?"]==1]

param_ranges = param_ranges.drop(["units", "References", "sensitivity analysis?", "optimisation?"], axis=1)
param_ranges = param_ranges.set_index("WOMBAT-full")
param_ranges
# Out:
#                    min       max  parameter number  optim number
# WOMBAT-full
# alphabio_phy         1         4                 1             1
# abioa_phy     0.000003  0.000017                 2             2
# bbioa_phy         1.04      1.08                 3             3
# alphabio_dia         1         4                 4             4
# alphabio_tri      0.25         2                 5             4
# ...                ...       ...               ...           ...
# sbac_kfer          0.1         2               101            34
# sbac_knh4         0.05       0.5               102            34
# sbac_fele         0.01       0.4               103            34
# baclmor             -4        -1               104            35
# bacqmor            0.0  0.000003               105            35
#
# [105 rows x 4 columns]

# %%
pd.set_option("display.precision", 16)
param_ranges.loc['abioa_phy']
# Out:
# min                 0.0000028935185185
# max                 0.0000173611111111
# parameter number                     2
# optim number                         2
# Name: abioa_phy, dtype: object

# %% [markdown]
# ### Create a normalized sobol sample

# %%
dim = len(param_ranges)
exps = 2048
sampler = qmc.Sobol(d=dim, scramble=True, seed=10)
sample_qmc = sampler.random(n=exps)  #here, n=256=2^8 
sample_qmc.shape
# Out:
# (2048, 105)

# %% [markdown]
# ### Create the parameter sets for our sensitivity experiments

# %%
param_sets = np.zeros((exps,dim))

# Loop over variables correctly
for ii, var in enumerate(param_ranges.index):
    param_sets[:, ii] = (
        param_ranges.loc[var, "min"]
        + (param_ranges.loc[var, "max"] - param_ranges.loc[var, "min"])
        * sample_qmc[:, ii]
    )

names = param_ranges.index
df_exps = pd.DataFrame(param_sets, columns=names)
df_norm = pd.DataFrame(sample_qmc, columns=names)
df_norm
# Out:
# WOMBAT-full        alphabio_phy           abioa_phy           bbioa_phy  \
# 0            0.9870995162054896  0.8023925330489874  0.0114757269620895
# 1            0.1607563057914376  0.1858798051252961  0.8527011051774025
# 2            0.2770723458379507  0.6762744421139359  0.3046449450775981
# 3            0.5761094130575657  0.3119522985070944  0.5831257356330752
# 4            0.6606289399787784  0.5214165896177292  0.9935524798929691
# ...                         ...                 ...                 ...
# 2043         0.6608627289533615  0.3094259537756443  0.2665728358551860
# 2044         0.5753688057884574  0.5217456687241793  0.1840944848954678
# 2045         0.2768325926735997  0.4040121259167790  0.9671991206705570
# 2046         0.1605209056288004  0.8978398712351918  0.3757012030109763
# 2047         0.9863621816039085  0.0279023665934801  0.7210612511262298
#
# WOMBAT-full        alphabio_dia        alphabio_tri           abioa_dia  \
# 0            0.1757747754454613  0.8299645446240902  0.0203756187111139
# 1            0.6923754466697574  0.0472765685990453  0.8318118341267109
# 2            0.3678662320598960  0.3189882505685091  0.7123426515609026
# 3            0.7653262726962566  0.5382677046582103  0.4047068618237972
# 4            0.9758513802662492  0.6563243726268411  0.1857881136238575
# ...                         ...                 ...                 ...
# 2043         0.5986805958673358  0.3145974110811949  0.8559916717931628
# 2044         0.6386437993496656  0.4424783550202847  0.5750629929825664
# 2045         0.2450904818251729  0.6607149662449956  0.2614992232993245
# 2046         0.8190575027838349  0.9554439950734377  0.1264050407335162
# 2047         0.2985510621219873  0.1756156114861369  0.9437692360952497
#
# WOMBAT-full           bbioa_dia               bbioh               phykn  \
# 0            0.0286230696365237  0.3057573009282351  0.7182503324002028
# 1            0.7949139643460512  0.9128264579921961  0.0826947139576077
# 2            0.2789400890469551  0.6279201349243522  0.4686745936051011
# 3            0.5440093288198113  0.0286825513467193  0.8322632927447557
# 4            0.4424664108082652  0.5681157782673836  0.2907311776652932
# ...                         ...                 ...                 ...
# 2043         0.4145562574267387  0.6140565052628517  0.7463718056678772
# 2044         0.5630046967417002  0.0432965075597167  0.1267142174765468
# 2045         0.3595847664400935  0.6757445475086570  0.5098331049084663
# 2046         0.8129021013155580  0.8981357309967279  0.8762832768261433
# 2047         0.1102136373519897  0.2578866351395845  0.2602559467777610
#
# WOMBAT-full               phykf  ...           obac_kdoc           obac_kfer  \
# 0            0.0698164757341146  ...  0.3402028754353523  0.7169372346252203
# 1            0.8974757678806782  ...  0.9057766897603869  0.1821135245263577
# 2            0.7315095625817776  ...  0.0205230200663209  0.4067593291401863
# 3            0.3099929820746183  ...  0.7098320219665766  0.9422405976802111
# 4            0.7612067805603147  ...  0.3940896540880203  0.0240564439445734
# ...                         ...  ...                 ...                 ...
# 2043         0.6615361422300339  ...  0.3445824412629008  0.2411974035203457
# 2044         0.1440381659194827  ...  0.5366523498669267  0.7915212400257587
# 2045         0.8154321694746614  ...  0.2249373439699411  0.3270100336521864
# 2046         0.5557387182489038  ...  0.8562847599387169  0.0821753237396479
# 2047         0.4779569087550044  ...  0.4209294570609927  0.5473440885543823
#
# WOMBAT-full           obac_knh4           obac_fele           sbac_kdoc  \
# 0            0.1080818716436625  0.4784427108243108  0.0071024764329195
# 1            0.9435305790975690  0.6677927067503333  0.9818280329927802
# 2            0.3010634724050760  0.2489938335493207  0.5319738248363137
# 3            0.6531070666387677  0.9343453412875533  0.4478614889085293
# 4            0.8695747703313828  0.1049230815842748  0.7422039248049259
# ...                         ...                 ...                 ...
# 2043         0.4482360891997814  0.7602661401033401  0.1788435997441411
# 2044         0.0432422244921327  0.2160292807966471  0.8805951373651624
# 2045         0.8796627875417471  0.9053191617131233  0.1089905425906181
# 2046         0.3658572519198060  0.4473956841975451  0.4084581639617682
# 2047         0.7169291134923697  0.6329312771558762  0.5706914616748691
#
# WOMBAT-full           sbac_kfer           sbac_knh4           sbac_fele  \
# 0            0.8242494817823172  0.6064235232770443  0.4753420110791922
# 1            0.1220681741833687  0.1708215111866593  0.9260499319061637
# 2            0.7104433644562960  0.9042410841211677  0.7486222907900810
# 3            0.4761086963117123  0.3436308447271585  0.1680325130000710
# 4            0.1517080431804061  0.4307974195107818  0.8147347159683704
# ...                         ...                 ...                 ...
# 2043         0.9941798308864236  0.2036539204418659  0.4151853527873755
# 2044         0.6316912863403559  0.0530112022534013  0.5698213456198573
# 2045         0.4279076196253300  0.7386209629476070  0.0214590970426798
# 2046         0.7789780776947737  0.4445935431867838  0.3429332794621587
# 2047         0.0442927330732346  0.7551960339769721  0.7633648850023746
#
# WOMBAT-full             baclmor             bacqmor
# 0            0.7857097964733839  0.6729492908343673
# 1            0.3242586785927415  0.2732354057952762
# 2            0.5747281294316053  0.1291670138016343
# 3            0.0352742010727525  0.7837781952694058
# 4            0.1634658379480243  0.5184305673465133
# ...                         ...                 ...
# 2043         0.2898795772343874  0.3904463863000274
# 2044         0.4176456332206726  0.1871055858209729
# 2045         0.9406132763251662  0.7746963584795594
# 2046         0.1911613941192627  0.6355185313150287
# 2047         0.6671323245391250  0.2930594300851226
#
# [2048 rows x 105 columns]

# %% [markdown]
# ### Save the parameter sets to an excel spreadsheet

# %%
# %%time
    
os.chdir(wrkdir)
df_exps.to_excel(wrkdir + '/parameter_sets_2048.xlsx')
df_exps.to_csv(wrkdir + '/parameter_sets_2048.txt', sep=' ')
df_norm.to_excel(wrkdir + '/parameter_norm_2048.xlsx')
df_norm.to_csv(wrkdir + '/parameter_norm_2048.txt', sep=' ')

# %%
os.getcwd()
# Out:
# '/g/data/vn19/pjb581/WOMBATmid-Optimization/data'
